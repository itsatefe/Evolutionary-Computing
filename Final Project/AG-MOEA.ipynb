# %%
from AGMOEA import AGMOEA
from ZDTEvaluator import ZDTEvaluator

# %%
crossover_parameters = {
    'sbx': {'eta': 20},
    'pcx': {'sigma': 0.1, 'eta': 0.1},
    'spx': {'epsilon': 1},
    'blx_alpha': {'alpha': 0.5},
    'de_rand_1': {'cr': 1,'f': 0.5}
}

# %%
NP = 300
K = 5
NGBA = 10
NEXA = 300
Tmax = 300
FETmax = 30000
N = 25
M = 3

# %%
NP = 100
K = 5
NGBA = 10
NEXA = 100
Tmax = 250
FETmax = 25000
N = 30
M = 2

# %%
problem_name = 'zdt1'
evaluator = ZDTEvaluator(problem_name, N,M)

# %%
agmoea = AGMOEA(NP, K, NGBA, NEXA, Tmax, FETmax, evaluator, crossover_parameters, N, M)

# %%
agmoea.agmoea_algorithm()
# Out:
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# [0.19855611 0.64867128]
# ...

# %%
import numpy as np
np.array([[1,2,3,5],[5223,533,323,55]]).shape
